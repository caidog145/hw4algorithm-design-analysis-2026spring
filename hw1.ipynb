# %% [markdown]
# ## algorithm design and anlysis-2026 spring  homework 1
# **Deadline**：2026.5.20
#
# **name**:
#
#
# note：
# ---
# 1. 带有\*的题目，申请免上课的同学，必须完成，其他同学选作；
# 2. 请独立完成，如求助了他人或者大模型，请著明，并且不可省略算法分析部分；
# 4. 如若作答有雷同，全部取消成绩；
# 3. 需要书面作答的题目，可以通过引用图片的形式添加，但是注意上传项目时包含所引用的图片的源文件；
# 4. $log_n$ 默认表示$log_2{n}$;

# %% [markdown]
# ## 问题 1
#
# 根据下列递归公式, 计算下列 $T(n)$ 对应的的渐近上界。要求所求的边界尽可能的紧（tight）, 请写明步骤。
#
# 1. $T(1)=1; T(n)=T(n/4)+1$ for $n>1$
# 2. $T(1)=1;T(n)=3T(n/3)+n^2$ for $n>1$
# 3. $T(1)=1;T(n)=T(2n/3)+1$ for $n>1$
# 4. $T(1)=1;T(n)=5T(n/4)+n$ for $n>1$
# 5. $T(n)=1 \ for\ n \le 2 ; T(n)=T(\sqrt{n})+1 \ for \ n>2$
#
# 答：
#
# 1. <br>
#
#    ![1-1](fig/1-1.png)
#
# 2. <br>
#
#    ![1-2](fig/1-2.png)
#
# 3. <br>
#
#    ![1-3](fig/1-3.png)
#
# 4. <br>
#
#    ![1-4](fig/1-4.png)
#
#    ![1-5](fig/1-5.png)
#
# 5. <br>
#
#    ![1-6](fig/1-6.png)
#
#    ![1-7](fig/1-7.png)

# %% [markdown]
# ## 问题 2
#
# 观察下方的分治算法（divide-and-conquer algorithm）的伪代码, 回答下面问题
#
# ```latex
# DoSomething(A,p,r)
# -----
# n := r-p+1
# if n=2 and A[p]>A[r] then
#     swap A[p] and A[r]
# else if n >= 3 then
#     m = ceil(2n/3)
#     DoSomething(A,p,p+m-1)
#     DoSomething(A,r-m+1,r)
#     DoSomething(A,p,p+m-1)
#
# ---
# first call: DoSomething(A,1,n)
# ```
#
# note：$ceil(2n/3)=\left\lceil {2n/3} \right\rceil$；$:=$ 表示赋值, 等价于 $\to$；A是一个包含n的整数元素的数组,
#
# 1. 写出该算法时间复杂度的递归公式, 并求解其对应的渐进表示
# 2. 描述一下该算法的功能, 并判断是否是最高效的解决方案
# 3. \* 使用python编程实现上述算法或其对应的更高效版本的算法

# %% [markdown]
# idea:
#
# 1. 时间复杂度递归式
#
#    ![2-1](fig/2-1.png)
#
#    ![2-2](fig/2-2.png)
#
# 2. 算法功能
#
#    ![2-3](fig/2-3.png)
#
# 3. 是否最高效
#
#    ![2-4](fig/2-4.png)

# %%
# algorithm time complexity is: O(n log n)
def merge_sort(A):
    if len(A) <= 1:
        return A

    mid = len(A) // 2
    left = merge_sort(A[:mid])
    right = merge_sort(A[mid:])

    return merge(left, right)


def merge(left, right):
    result = []
    i = 0
    j = 0

    while i < len(left) and j < len(right):
        if left[i] <= right[j]:
            result.append(left[i])
            i += 1
        else:
            result.append(right[j])
            j += 1

    result.extend(left[i:])
    result.extend(right[j:])
    return result


# test
A = [5, 3, 8, 1, 2, 7, 4, 6]
print(merge_sort(A))
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %% [markdown]
# ## 问题 3
#
# 给定一个包含n个元素的数组 `profits` , 它的第 `i` 个元素 `profits[i]` 表示一支股票第 `i` 天的**收益**（正数表示涨, 负数表示跌）。你只能选择 **某一天** 买入这只股票, 并选择在 **未来的某一个不同的日子** 卖出该股票。
#
# 1. 设计一个算法来计算你所能获取的最大利润和对应买入和卖出的日期。请分析算法方案, 计算其时间复杂度, 并且使用python编程实现该算法。
#
# 2. \* 设计一个时间复杂度为 $O(n)$的算法实现该算法
#
# e.g. :
# ---
# profits=[3,2,1,-7,5,2,-1,3,-1], 第5天买入, 第8天卖出, 收益最大：9

# %% [markdown]
# idea:
#
# 算法方案:
#
# 从左到右遍历数组，维护两个变量：
#
# current_sum：表示以当前日期结尾的最大连续利润。
#
# max_sum：表示目前找到的最大利润。
#
# 如果 current_sum<0，说明前面的收益会拖累后面的结果，因此从当前这一天重新开始计算利润。
#
# 如果 current_sum≥0，说明前面的收益对后面有帮助，可以继续累加当前收益。
#
# 同时记录当前区间的起点，以及最大利润对应的买入日期和卖出日期。
#
#
# 时间复杂度分析:
#
# 该算法只对数组进行一次遍历。
#
# 假设数组长度为 n，循环执行 n−1 次，每次循环中只进行常数次比较、加法和赋值操作。
#
# 因此时间复杂度为 O(n)

# %%
# algorithm time complexity is: O(n)
def max_profit(profits):
    n = len(profits)

    current_sum = profits[0]
    max_sum = profits[0]

    start = 0
    buy_day = 0
    sell_day = 0

    for i in range(1, n):
        if current_sum < 0:
            current_sum = profits[i]
            start = i
        else:
            current_sum += profits[i]

        if current_sum > max_sum:
            max_sum = current_sum
            buy_day = start
            sell_day = i

    return max_sum, buy_day + 1, sell_day + 1


profits = [3, 2, 1, -7, 5, 2, -1, 3, -1]

profit, buy, sell = max_profit(profits)

print("最大利润:", profit)
print("买入日期: 第", buy, "天")
print("卖出日期: 第", sell, "天")
# Out:
# 最大利润: 9
# 买入日期: 第 5 天
# 卖出日期: 第 8 天

# %% [markdown]
# ## 问题 4
#
# 给定一个包含不同整数元素的数组 $ A[1..n]$ ,并且满足条件：$A[1]>A[2]$ 并且 $A[n-1]<A[n]$; 规定：如果一个元素比它两边的邻居元素都小, 即：$A[x]<A[x-1], A[x]<A[x+1]$ , 称这个元素A[x]为“局部最小”。通过遍历一次数组, 我们可以很容易在 $O(n)$的时间复杂度下找到一个局部最小值,
#
#
# 1. 分析该问题, 设计一个算法在$O(logn)$的时间复杂度下找到一个局部最小(返回数值), 要求：分析算法设计思路, 并且使用python编程实现
# 2. \* 设计算法找出所有局部最小值, 分析算法设计思路, 并使用python编程实现
#
# e.g.:
# ---
# A=[9, 3, 7, 2, 1, 4, 5 ] 时,  局部最小元素为 3, 1

# %% [markdown]
# idea:
#
# 使用二分查找。
#
# 设查找范围为数组中间部分，因为局部最小值需要同时有左右邻居，所以只需要检查：
#
# A[2] 到 A[n−1]
#
# 每次取中间位置 mid。
#
# 如果 A[mid]<A[mid−1] 且 A[mid]<A[mid+1]
#
# 那么 A[mid] 就是局部最小值，直接返回。
#
# 如果 A[mid]>A[mid−1]
#
# 说明左边相邻元素更小，因此左半部分一定存在局部最小值，于是继续在左半部分查找。
#
# 如果 A[mid]>A[mid+1]
#
# 说明右边相邻元素更小，因此右半部分一定存在局部最小值，于是继续在右半部分查找。
#
# 由于每次都把查找范围缩小一半，所以时间复杂度为 O(logn)

# %%
# algorithm time complexity is: O(logn)
def find_local_min(A):
    n = len(A)

    left = 1
    right = n - 2

    while left <= right:
        mid = (left + right) // 2

        if A[mid] < A[mid - 1] and A[mid] < A[mid + 1]:
            return A[mid]

        elif A[mid] > A[mid - 1]:
            right = mid - 1

        else:
            left = mid + 1

    return None


A = [9, 3, 7, 2, 1, 4, 5]
print(find_local_min(A))
# Out:
# 1

# %% [markdown]
# ## 问题 5
#
# 给定包含n个不同数字的一组数, 寻找一种基于比较的算法在这组数中找到k个最小的数字, 并按顺序输出它们。
#
# 1. 将n个数先进行排序, 然后按顺序输出最小的k个数。要求：选择合适的排序算法实现上述操作, 计算算法时间复杂度, 并使用python编程实现。
# 2. 建立一个包含这n个数的堆（heap）, 并且调用 k 次Extract-min 按顺序输出最小的k个数。使用往空堆中不断插入元素的方法建立堆, 分析这种方法建堆的时间复杂度, 并使用python编程实现
# 3. \* 假设数组中包含的数据总数目超过了计算机的存储能力, 请设计一个算法, 找到这堆数据的前k小的数值, 计算时间复杂度, 并使用python实现该算法, 假设计算机一定能存储k个数据。
#
# e.g.：
# ---
# 数组arr=[5,4,3,2,6,1,88,33,22,107] 的前3个最小数据为：1, 2, 3

# %% [markdown]
# idea:
#
# 第一问：
#
# 算法思路：
#
# 先对数组进行升序排序，然后输出排序后数组的前 k 个元素。
#
# 时间复杂度：
#
# 排序需要 O(nlogn)，输出前 k 个元素需要 O(k)。所以总时间复杂度为 O(nlogn+k)
#
# 因为 k≤n，所以可以写成 O(nlogn)
#
#
# 第二问时间复杂度分析：
#
# 设当前堆中已经有 i 个元素，此时再插入一个新元素。
#
# 插入后，需要从堆底向上调整，最坏情况下调整高度为 O(logi)
#
# 所以第 1 个元素插入代价为 O(log1)
#
# 第 2 个元素插入代价为 O(log2)
#
# 第 3 个元素插入代价为 O(log3)
#
# ……
#
# 第 n 个元素插入代价为 O(logn)
#
# 因此，总建堆时间为 O(log1+log2+log3+⋯+logn)
#
# 也就是 O(log(n!))
#
# 根据渐近关系 log(n!)=O(nlogn)
#
# 所以使用不断插入元素的方式建堆，时间复杂度为 O(nlogn)

# %%
# 第一问
# algorithm time complexity is: O(nlogn)
def find_k_smallest_by_sort(arr, k):
    arr_sorted = sorted(arr)
    return arr_sorted[:k]


arr = [5, 4, 3, 2, 6, 1, 88, 33, 22, 107]
k = 3

result = find_k_smallest_by_sort(arr, k)
print(result)
# Out:
# [1, 2, 3]

# %%
# 第二问
# algorithm time complexity is: O(nlogn)
import heapq

def find_k_smallest_by_heap(arr, k):
    heap = []

    for x in arr:
        heapq.heappush(heap, x)

    result = []

    for _ in range(k):
        result.append(heapq.heappop(heap))

    return result


arr = [5, 4, 3, 2, 6, 1, 88, 33, 22, 107]
k = 3

result = find_k_smallest_by_heap(arr, k)
print(result)
# Out:
# [1, 2, 3]

# %% [markdown]
# ## 问题 6
#
# > 星球碰撞问题：现有n个星球，在同一条直线上运行，如数组A所示，元素的绝对值表示星球的质量，负数表示星球自右向左运动，正数表示星球自左向右运动，当两个星球相撞的时候，质量小的会消失，大的保持不变，**质量相同的两个星球碰撞后自右向左运动的星球消失，自左向右的星球保持不变**，假设所有星球的速度大小相同。
# >
# > $ A=[23,-8, 9, -3, -7, 9, -23, 22] $
#
# 请设计一个算法模拟星球的运行情况，输出最终的星球存续情况（输出一个数组），分析算法设计思路，计算时间复杂度，并基于python编程实现。
#
# e.g.
# ---
# 1.  输入： A=[-3,-6,2,8, 5,-8,9,-2,1]， 输出：[-3, -6, 2, 8, 9, 1]
#
# 2. 输入：A=[23,-8, 9, -3, -7, 9, -23, 22], 输出：[23, 22]

# %% [markdown]
# idea:
#
# 使用一个栈保存当前仍然存在的星球。
#
# 从左到右遍历数组中的每个星球 x。
#
# 只有当栈顶星球向右运动，当前星球向左运动时，才会发生碰撞，即：
#
# stack[−1]>0且x<0
#
# 碰撞时分三种情况：
#
# 如果∣stack[−1]∣<∣x∣
#
# 说明栈顶星球质量较小，栈顶星球消失，当前星球继续与前面的星球比较。
#
# 如果∣stack[−1]∣>∣x∣
#
# 说明当前星球质量较小，当前星球消失。
#
# 如果：∣stack[−1]∣=∣x∣
#
# 那么当前星球 x 消失，栈顶星球保留。
#
#
# 时间复杂度为 O(n)

# %%
# algorithm time complexity is: O(n)
def planet_collision(A):
    stack = []

    for x in A:
        alive = True

        while alive and stack and stack[-1] > 0 and x < 0:
            if abs(stack[-1]) < abs(x):
                stack.pop()
            elif abs(stack[-1]) == abs(x):
                # 质量相同，自右向左的星球消失
                alive = False
            else:
                # 当前星球质量小，当前星球消失
                alive = False

        if alive:
            stack.append(x)

    return stack


A = [23, -8, 9, -3, -7, 9, -23, 22]
print(planet_collision(A))
# Out:
# [23, 22]

# %% [markdown]
# ## 问题 7
#
# > 0-1背包问题：现在有4块大理石，每个大理石对应的重量和价值使用一个元组表示, 即（重量，价值），4块大理石的重量和价值为：[(5,10), (4,40), (6,30), (3, 50)], 假设你有一辆最大承重为9的小推车，请问使用这个小推车装大理石的最大价值为多少
#
# 请设计一个算法解决该问题，分析算法设计思路，计算时间复杂度，并基于python编程实现

# %% [markdown]
# idea:
#
# 每块大理石只有两种选择：
#
# 选：放入小推车
#
# 不选：不放入小推车
#
# 设 dp[i][w] 表示在前 i 块大理石中，当前承重不超过 w 时能够获得的最大价值。
#
# 对于第 i 块大理石，设它的重量为 weight，价值为 value。
#
# 如果当前容量 w 放不下第 i 块大理石，则dp[i][w]=dp[i−1][w]
#
# 如果当前容量 w 可以放下第 i 块大理石，则有两种选择：
#
# 不选第 i 块 dp[i−1][w]
#
# 选第 i 块 dp[i−1][w−weight]+value
#
# 所以状态转移方程为dp[i][w]=max(dp[i−1][w],dp[i−1][w−weight]+value)
#
# 最后 dp[n][W] 就是最大价值。
#
#
# 时间复杂度分析
#
# 外层循环遍历 n 块大理石。内层循环遍历容量 W。
#
# 所以时间复杂度为 O(nW)
#
# 其中 n 是大理石数量，W 是小推车最大承重。

# %%
# algorithm time complexity is: O(nW)
def knapsack(items, capacity):
    n = len(items)

    dp = [[0] * (capacity + 1) for _ in range(n + 1)]

    for i in range(1, n + 1):
        weight, value = items[i - 1]

        for w in range(1, capacity + 1):
            if weight > w:
                dp[i][w] = dp[i - 1][w]
            else:
                dp[i][w] = max(
                    dp[i - 1][w],
                    dp[i - 1][w - weight] + value
                )

    selected = []
    w = capacity

    for i in range(n, 0, -1):
        if dp[i][w] != dp[i - 1][w]:
            selected.append(i)
            w -= items[i - 1][0]

    selected.reverse()

    return dp[n][capacity], selected


items = [(5, 10), (4, 40), (6, 30), (3, 50)]
capacity = 9

max_value, selected_items = knapsack(items, capacity)

print("最大价值:", max_value)
print("选择的大理石编号:", selected_items)
# Out:
# 最大价值: 90
# 选择的大理石编号: [2, 4]

# %% [markdown]
# ## 问题 8
#
# 给你二叉搜索树的根节点 root ，该树中的恰好两个节点的值被错误地交换。请在不改变其结构的情况下，恢复这棵树 。设计算法解决该问题，分析算法设计思路，计算时间复杂度，并基于python编程实现
#
# e.g.:
# ---
# 1.
#
# <div style="text-align:center;width:200px;"> <img alt="" src="./fig/hw3q9-1.jpg"> </div>
# 输入：root = [1,3,null,null,2]， 输出为：[3,1,null,null,2]，
#
# 解释：3 不能是 1 的左孩子，因为 3 > 1 。交换 1 和 3 使二叉搜索树有效。
#
# 2.
#
#  <div style="text-align:center;width:200px;"> <img alt="" src="./fig/hw3q9-1.jpg"> </div>
# 输入： root=[3,1,4,null,null,2]， 输出为：[2,1,4,null,null,3]
#
# 解释：2 不能在 3 的右子树中，因为 2 < 3 。交换 2 和 3 使二叉搜索树有效。

# %% [markdown]
# idea:
#
# 设 prev 表示中序遍历中当前节点的前一个节点。
#
# 如果发现：
#
# prev.val > root.val
#
# 说明这里出现了错误顺序。
#
# 第一次发现错误时，较大的那个 prev 一定是第一个错误节点。
#
# 之后发现错误时，较小的那个 root 是第二个错误节点。
#
# 最后只需要交换这两个节点的值即可，不需要改变树的结构。

# %%
# algorithm time complexity is: O(n)

from collections import deque

class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right


def build_tree(values):
    if not values or values[0] is None:
        return None

    root = TreeNode(values[0])
    queue = deque([root])
    i = 1

    while queue and i < len(values):
        node = queue.popleft()

        if i < len(values) and values[i] is not None:
            node.left = TreeNode(values[i])
            queue.append(node.left)
        i += 1

        if i < len(values) and values[i] is not None:
            node.right = TreeNode(values[i])
            queue.append(node.right)
        i += 1

    return root


def tree_to_list(root):
    if not root:
        return []

    result = []
    queue = deque([root])

    while queue:
        node = queue.popleft()

        if node:
            result.append(node.val)
            queue.append(node.left)
            queue.append(node.right)
        else:
            result.append(None)

    while result and result[-1] is None:
        result.pop()

    return result


def recoverTree(root):
    first = None
    second = None
    prev = None

    def inorder(node):
        nonlocal first, second, prev

        if node is None:
            return

        inorder(node.left)

        if prev is not None and prev.val > node.val:
            if first is None:
                first = prev
            second = node

        prev = node

        inorder(node.right)

    inorder(root)

    if first is not None and second is not None:
        first.val, second.val = second.val, first.val

    return root


# 测试 1
root1 = build_tree([1, 3, None, None, 2])
recoverTree(root1)
print(tree_to_list(root1))

# 测试 2
root2 = build_tree([3, 1, 4, None, None, 2])
recoverTree(root2)
print(tree_to_list(root2))
# Out:
# [3, 1, None, None, 2]
# [2, 1, 4, None, None, 3]

# %% [markdown]
# ## 问题 9 \*
# 给定 `n` 个非负整数表示每个宽度为 `1` 的柱子的高度图，计算按此排列的柱子，下雨之后能接多少雨水。
#
#
#
# <div style="text-align:center;width:800px;"> <img alt="" src="./fig/hw3q6.png"> </div>
#
# 请分析算法设计思路，计算时间复杂度，并基于python编程实现

# %% [markdown]
# idea:

# %%
# add your code here
# your algorithm time complexity is:

# %% [markdown]
# ## 问题 10
#
# 给你一个二叉树的根节点 root ，树中每个节点都存放有一个 0 到 9 之间的数字。每条从根节点到叶节点的路径都代表一个数字：
#
# > 例如，从根节点到叶节点的路径 1 -> 2 -> 3 表示数字 123 。
#
# 设计一个算法计算从根节点到叶节点生成的所有数字之和 ，分析算法设计思路，计算时间复杂度，并基于python编程实现
#
# 叶节点:是指没有子节点的节点。
#
# e.g.:
# ---
# 1.
#
#  <div style="text-align:center;width:200px;"> <img alt="figure" src="./fig/hw3q10-1.jpg"> </div>
#
#  输入：root = [1,2,3], 输出：25
#
# 解释：从根到叶子节点路径 1->2 代表数字 12，1->3 代表数字 13，因此和为 12 + 13 = 25 。
#
# 2.
#
#  <div style="text-align:center;width:200px;"> <img alt="figure" src="./fig/hw3q10-2.jpg"> </div>
#
#  输入：root = [4,9,0,5,1], 输出：1026
#
# 解释：从根到叶子节点路径 4->9->5 代表数字 495，4->9->1 代表数字 491，4->0 代表数字 40。因此和为 495 + 491 + 40 = 1026 。

# %% [markdown]
# idea:
#
# 使用深度优先搜索遍历二叉树。
#
# 从根节点开始向下遍历，用一个变量 current 记录从根节点到当前节点形成的数字。
#
# 每访问一个节点，就把当前数字更新为current=current×10+node.val
#
# 如果当前节点不是叶子节点，就继续遍历它的左子树和右子树。
#
# 如果当前节点是叶子节点，说明已经得到了一条完整的根节点到叶子节点路径，此时将 current 加入结果中。
#
# 最后，把所有叶子节点对应路径形成的数字相加。

# %%
# algorithm time complexity is:  O(n)

from collections import deque

class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right


def sumNumbers(root):
    def dfs(node, current):
        if node is None:
            return 0

        current = current * 10 + node.val

        if node.left is None and node.right is None:
            return current

        return dfs(node.left, current) + dfs(node.right, current)

    return dfs(root, 0)


def build_tree(values):
    if not values:
        return None

    root = TreeNode(values[0])
    queue = deque([root])
    i = 1

    while queue and i < len(values):
        node = queue.popleft()

        if i < len(values) and values[i] is not None:
            node.left = TreeNode(values[i])
            queue.append(node.left)
        i += 1

        if i < len(values) and values[i] is not None:
            node.right = TreeNode(values[i])
            queue.append(node.right)
        i += 1

    return root


# 测试 1
root1 = build_tree([1, 2, 3])
print(sumNumbers(root1))

# 测试 2
root2 = build_tree([4, 9, 0, 5, 1])
print(sumNumbers(root2))
# Out:
# 25
# 1026
